# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# As an advisor to state governments aiming to improve the average SAT and ACT scores, I will be using data-backed evidence to recommend whether there is value to provide free or compulsory statewide assessments (SAT or ACT) to improve students' scores and chances of getting into a college of their choice.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ## Choosing Data

# %% [markdown]
# For this project, I will be using the following datasets:
#
# The following ACT datasets from 2017 to 2019 describe the Participation rate and Composite Test scores for all 50 US states. The ACT 2017 dataset also contains the individual ACT subjects' test scores.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
#
# The following SAT datasets from 2017 to 2019 contain the Participation rate and Subject and Total Test scores for all 50 US states.
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
#
# The following datasets from the US Census Bureau contain data about the each state such as the spending on education, mean wage etc.
# * [`US Census Data`](./data/US Census Bureau.xlsx): containing the following datasets
# - a. Median household income of Overall US and all US states from 2017 to 2019
# - b. Per Capita Income of Overall and all US states
# - c. US Population data with proportion of population with Bachelor's Degree or higher
# - d. Each US State's spending per pupil
#
# (US Census data obtained from:https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_income (data.census.gov)
#
#
# On US income:
#
# Median household income was USD 68,703 in 2019, an increase of 6.8 percent from the 2018 median of USD 64,324. The 2019 real median incomes of family households and nonfamily households increased 7.3 percent and 6.2 percent from their respective 2018 estimates.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Making standardized testing compulsory and/or free for students has been a trend of state governments.
#
# According to a Los Angeles Times article (https://www.latimes.com/local/education/la-me-edu-lausd-sat-juniors-20190330-story.html), LA had all juniors take the SAT, a standardized college admissions test, on a school day, for free. This increases access to higher education for low-income students. Most four-year colleges require applicants to take either the SAT or the ACT. Experts recommend giving the tests a first try during junior year.
#
#
# **Below are some of the policies of different states**
# (Information from: https://mindfish.com/which-states-require-the-sat/, updated as of 2020)
#
# **The States that Require the SAT**
#
# The following states require high school juniors to take the SAT and offer the test as part of statewide assessments:
#
# - Colorado
# - Connecticut
# - Delaware
# - Illinois
# - Michigan
# - New Hampshire
# - Rhode Island
# - West Virginia
#
# **Some states with other arrangements for the SAT**
#
# - The District of Columbia: does not require students to take the SAT but offers the test for free to all juniors and seniors.
# - Idaho: offers the SAT through the School Day Test. Juniors are required to take either the SAT or ACT.
# - Maine: Taking the SAT is optional for Maine juniors, but the state still offers it to its students for free.
# - Tennessee: Students are required to take either the SAT or the ACT.
# - Ohio: Students are required to take either the SAT or the ACT. Individual school districts within Ohio can select which test they will give.
# - Oklahoma: Students are required to take either the SAT or the ACT, but it varies from school district to school district within the state.
# - South Carolina: Students are required to take either the SAT or the ACT, but it varies from school district to school district within the state.

# %% [markdown]
# (Information from: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice)
#
# **The States that Require the ACT**
# - Alabama
# - Hawaii
# - Montana
# - Nebraska
# - Nevada
# - North Carolina
# - North Dakota
# - Wisconsin
# - Kentucky (no Writing)
# - Louisiana (no Writing)
# - Mississippi (no Writing)
# - Utah (no Writing)
# - Wyoming (no Writing)
#
# **Some states with other arrangements for the ACT**
# - Arkansas — offered but not required; no Writing
# - Kansas — offered but not required; no Writing
# - Minnesota — SAT or ACT offered
# - Ohio — SAT or ACT required; district determines which test
# - Oklahoma — SAT or ACT required; district determines which test
# - South Carolina — SAT or ACT required
# - Tennessee — SAT or ACT required (districts may provide either SAT or ACT or allow students to choose)

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
list_ = [2,4,6,8,100] #Test

# %%
def calculate_mean(testlist):
    total = 0
    count = 0
    for i in testlist:
        if i>=0:
            total += i
            count += 1

    mean = total/count
    return mean

# %%
calculate_mean(list_)
# Out:
# 24.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def calculate_sd(col):

    mean = calculate_mean(col)
    total = 0
    
    for x in col:
        total += (x-mean)**2
        
    n = len(col)    
    variance = total / n
    sd = variance**(0.5)  
    
    return sd

# %%
calculate_sd(list_)
# Out:
# 38.05259518088089

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def convertpercentage(percent): #input is a string
    return round(float(percent[:-1])/100,3)

# %%
percent = '99.5%'
convertpercentage(percent)
# Out:
# 0.995

# %%
type(convertpercentage(percent))
# Out:
# float

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %% [markdown]
# #### 1. Import and Display the data

# %% [markdown]
# Read in SAT 2017 - 2019 datasets

# %%
filepath = '../data/'

# %%
#Read in SAT datasets, creating a column 'Year' in the process
df_sat2017 = pd.read_csv(filepath + 'sat_2017.csv')
df_sat2018 = pd.read_csv(filepath + 'sat_2018.csv')
df_sat2019 = pd.read_csv(filepath + 'sat_2019.csv')

#df_sat2017['Year'] = 2017
#df_sat2018['Year'] = 2018
#df_sat2019['Year'] = 2019

# %%
df_sat2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
df_sat2017.shape
# Out:
# (51, 5)

# %%
df_sat2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
df_sat2018.shape
# Out:
# (51, 5)

# %%
df_sat2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
df_sat2019.shape
# Out:
# (53, 5)

# %%
#Remove Puerto Rico and Virgin Islands from dataset as they have no participation rates as these rows are unnecessary
df_sat2019 = df_sat2019[~(df_sat2019['State'] == 'Puerto Rico') & ~(df_sat2019['State'] == 'Virgin Islands') ]

# %%
df_sat2019.shape
# Out:
# (51, 5)

# %% [markdown]
# Read in ACT 2017 - 2019 datasets

# %%
#Read in ACT 2017 - 2019 datasets, adding year in the process

df_act2017 = pd.read_csv(filepath + 'act_2017.csv')
df_act2018 = pd.read_csv(filepath + 'act_2018.csv')
df_act2019 = pd.read_csv(filepath + 'act_2019.csv')

#df_act2017['Year'] = 2017
#df_act2018['Year'] = 2018
#df_act2019['Year'] = 2019

# %%
df_act2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
df_act2017.shape #ACT 2017 contains the individual subject test scores while 2018-2019 doesn't
# Out:
# (52, 7)

# %%
df_act2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_act2018.shape
# Out:
# (52, 3)

# %%
df_act2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
df_act2019.shape
# Out:
# (52, 3)

# %% [markdown]
# #### 2. Check the Data types of all dataframes

# %%
df_sat2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_sat2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
df_sat2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
df_act2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
df_act2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
df_act2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
# convert all participation rates to float
df_sat2017['Participation'] = df_sat2017['Participation'].apply(convertpercentage)
df_sat2018['Participation'] = df_sat2018['Participation'].apply(convertpercentage)
df_sat2019['Participation Rate'] = df_sat2019['Participation Rate'].apply(convertpercentage)

# %%
df_act2017['Participation'] = df_act2017['Participation'].apply(convertpercentage)
df_act2018['Participation'] = df_act2018['Participation'].apply(convertpercentage)
df_act2019['Participation'] = df_act2019['Participation'].apply(convertpercentage)

# %%
# ACT 2017 Composite score should be float data type, not object. 
# This function converts everything to float and to removes the last char x from the one that is not float type

def cleaning(row):
    try:
        output = float(row)
    except:
        output = float(row[:-1]) #since the error is additional char 'x' at the back
    
    return output

# %%
df_act2017['Composite'] = df_act2017['Composite'].map(cleaning)

# %% [markdown]
# Composite score of the state of Wyoming for 2017 is fixed.

# %%
#Change 'District of columbia' to 'District of Columbia' in ACT 2018 dataset.
df_act2018['State'][8] = 'District of Columbia'
# Out:
# C:\Users\gohch\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest)

# %%
df_sat2017.describe() #The min value for Math is too low, causing std deviation to be almost twice that of EBRW.
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.398039                          569.117647  547.627451
# std         0.352766                           45.666901   84.909119
# min         0.020000                          482.000000   52.000000
# 25%         0.040000                          533.500000  522.000000
# 50%         0.380000                          559.000000  548.000000
# 75%         0.660000                          613.000000  599.000000
# max         1.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
df_sat2018.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.457451                          563.686275  556.235294
# std         0.373143                           47.502627   47.772623
# min         0.020000                          480.000000  480.000000
# 25%         0.045000                          534.500000  522.500000
# 50%         0.520000                          552.000000  544.000000
# 75%         0.775000                          610.500000  593.500000
# max         1.000000                          643.000000  655.000000
#
#              Total
# count    51.000000
# mean   1120.019608
# std      94.155083
# min     977.000000
# 25%    1057.500000
# 50%    1098.000000
# 75%    1204.000000
# max    1298.000000

# %%
df_sat2019.describe()
# Out:
#        Participation Rate        EBRW        Math        Total
# count           51.000000   51.000000   51.000000    51.000000
# mean             0.490588  560.803922  552.196078  1113.078431
# std              0.387476   46.248035   51.290553    97.197910
# min              0.020000  483.000000  460.000000   943.000000
# 25%              0.055000  527.500000  511.500000  1038.000000
# 50%              0.540000  550.000000  546.000000  1097.000000
# 75%              0.820000  612.000000  599.000000  1210.000000
# max              1.000000  636.000000  648.000000  1284.000000

# %%
df_act2017.describe()
# Out:
#        Participation    English       Math    Reading    Science  Composite
# count      52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean        0.651538  20.919231  21.173077  22.001923  21.040385  21.509615
# std         0.318325   2.332132   1.963602   2.048672   3.151113   2.002083
# min         0.080000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%         0.310000  19.000000  19.400000  20.475000  19.900000  19.800000
# 50%         0.680000  20.550000  20.900000  21.700000  21.150000  21.400000
# 75%         1.000000  23.300000  23.100000  24.125000  22.525000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000

# %%
df_act2018.describe()
# Out:
#        Participation  Composite
# count      52.000000  52.000000
# mean        0.606731  21.544231
# std         0.345456   2.119417
# min         0.070000  17.700000
# 25%         0.270000  19.975000
# 50%         0.655000  21.300000
# 75%         1.000000  23.725000
# max         1.000000  25.600000

# %%
df_act2019.describe()
# Out:
#        Participation  Composite
# count      52.000000  52.000000
# mean        0.585385  21.450000
# std         0.341883   2.175487
# min         0.060000  17.900000
# 25%         0.247500  19.800000
# 50%         0.530000  20.950000
# 75%         1.000000  23.650000
# max         1.000000  25.500000

# %%
sns.boxplot(df_sat2017['Math']);

# %%
# There is an apparent outlier in the SAT 2017 Math, and ACT 2017 Science ACT scores - to impute with the likely values (x10)

df_sat2017 = df_sat2017.sort_values(['Math']).reset_index(drop=True) #reorder index
df_sat2017['Math'][0] = df_sat2017['Total'][0] - df_sat2017['Evidence-Based Reading and Writing'][0]

state = df_sat2017['State'][0]
new_score = df_sat2017['Math'][0]
print(f'The Math score of the state of {state} has been fixed to {new_score}.')
# Out:
# The Math score of the state of Maryland has been fixed to 524.
# C:\Users\gohch\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_sat2017.head() #Fixed the outlier
# Out:
#                   State  Participation  Evidence-Based Reading and Writing  \
# 0              Maryland           0.69                                 536
# 1  District of Columbia           1.00                                 482
# 2              Delaware           1.00                                 503
# 3                 Idaho           0.93                                 513
# 4              Michigan           1.00                                 509
#
#    Math  Total
# 0   524   1060
# 1   468    950
# 2   492    996
# 3   493   1005
# 4   495   1005

# %% [markdown]
# #### 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
df_sat2017.describe()
# Out:
#        Participation  Evidence-Based Reading and Writing        Math  \
# count      51.000000                           51.000000   51.000000
# mean        0.398039                          569.117647  556.882353
# std         0.352766                           45.666901   47.121395
# min         0.020000                          482.000000  468.000000
# 25%         0.040000                          533.500000  523.500000
# 50%         0.380000                          559.000000  548.000000
# 75%         0.660000                          613.000000  599.000000
# max         1.000000                          644.000000  651.000000
#
#              Total
# count    51.000000
# mean   1126.098039
# std      92.494812
# min     950.000000
# 25%    1055.500000
# 50%    1107.000000
# 75%    1212.000000
# max    1295.000000

# %%
sns.boxplot(df_act2017['Science']);

# %%
df_act2017.iloc[21,:] #Change Wyoming composite to float
# Out:
# State            Maryland
# Participation        0.28
# English              23.3
# Math                 23.1
# Reading              24.2
# Science               2.3
# Composite            23.6
# Name: 21, dtype: object

# %%
df_act2017 = df_act2017.sort_values(['Science']).reset_index(drop=True) #reorder index
df_act2017['Science'][0] = round(df_act2017['Composite'][0] * 4 - (df_act2017['English'][0] + df_act2017['Math'][0] + df_act2017['Reading'][0]), 1)

state = df_act2017['State'][0]
new_score = df_act2017['Science'][0]
print(f'The science score of the state of {state} has been fixed to {new_score}.')
# Out:
# The science score of the state of Maryland has been fixed to 23.8.
# C:\Users\gohch\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_act2017.describe()
# Out:
#        Participation    English       Math    Reading    Science  Composite
# count      52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean        0.651538  20.919231  21.173077  22.001923  21.453846  21.509615
# std         0.318325   2.332132   1.963602   2.048672   1.737303   2.002083
# min         0.080000  16.300000  18.000000  18.100000  18.200000  17.800000
# 25%         0.310000  19.000000  19.400000  20.475000  19.975000  19.800000
# 50%         0.680000  20.550000  20.900000  21.700000  21.300000  21.400000
# 75%         1.000000  23.300000  23.100000  24.125000  23.200000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000

# %% [markdown]
# #### Rename Columns and merge dataframes
# Note: Column names should be all lowercase.
# Column names should not contain spaces

# %%
sat_new_names = {
            "State": "state",
            "Participation Rate": "sat_part", 
            "Participation": "sat_part",
            "EBRW": "sat_ebrw",
            "Evidence-Based Reading and Writing" : "sat_ebrw",
            "Math" : "sat_math",
            "Total" : "sat_total",
            }

# %%
df_sat2017.rename(columns = sat_new_names, inplace = True)
df_sat2018.rename(columns = sat_new_names, inplace = True)
df_sat2019.rename(columns = sat_new_names, inplace = True)

# %%
df_sat = df_sat2017.merge(df_sat2018, on = 'state', suffixes=('_17', '_18'))

#df_sat_act = df_sat.merge(df_act, how= 'left', on=['state','year'])

# %%
df_sat = df_sat.merge(df_sat2019, on = 'state', suffixes=('', '_19'))

# %%
df_sat.head()
# Out:
#                   state  sat_part_17  sat_ebrw_17  sat_math_17  sat_total_17  \
# 0              Maryland         0.69          536          524          1060
# 1  District of Columbia         1.00          482          468           950
# 2              Delaware         1.00          503          492           996
# 3                 Idaho         0.93          513          493          1005
# 4              Michigan         1.00          509          495          1005
#
#    sat_part_18  sat_ebrw_18  sat_math_18  sat_total_18  sat_part  sat_ebrw  \
# 0         0.76          545          535          1080      0.82       535
# 1         0.92          497          480           977      0.94       495
# 2         1.00          505          492           998      1.00       499
# 3         1.00          508          493          1001      1.00       505
# 4         1.00          511          499          1011      1.00       507
#
#    sat_math  sat_total
# 0       523       1058
# ...

# %%
sat_new_names_19 = {
            "sat_part": "sat_part_19",
            "sat_ebrw": "sat_ebrw_19",
            "sat_math" : "sat_math_19",
            "sat_total" : "sat_total_19",
            }

df_sat.rename(columns = sat_new_names_19, inplace = True)

# %%
df_sat.head()
# Out:
#                   state  sat_part_17  sat_ebrw_17  sat_math_17  sat_total_17  \
# 0              Maryland         0.69          536          524          1060
# 1  District of Columbia         1.00          482          468           950
# 2              Delaware         1.00          503          492           996
# 3                 Idaho         0.93          513          493          1005
# 4              Michigan         1.00          509          495          1005
#
#    sat_part_18  sat_ebrw_18  sat_math_18  sat_total_18  sat_part_19  \
# 0         0.76          545          535          1080         0.82
# 1         0.92          497          480           977         0.94
# 2         1.00          505          492           998         1.00
# 3         1.00          508          493          1001         1.00
# 4         1.00          511          499          1011         1.00
#
#    sat_ebrw_19  sat_math_19  sat_total_19
# 0          535          523          1058
# ...

# %%
act_new_names = {"State": "state",
            "Participation Rate": "act_part", 
            "Participation": "act_part",
            "English": "act_eng_17",
            "Math" : "act_math_17",
            "Reading" : "act_reading_17",
            "Science" : "act_science_17",
            "Composite" : "act_composite",
            "Year" : "year"}

# %%
df_act2017.rename(columns = act_new_names , inplace = True)
df_act2018.rename(columns = act_new_names , inplace = True)
df_act2019.rename(columns = act_new_names , inplace = True)
#df_act = pd.concat([df_act2017, df_act2018, df_act2019])

# %%
df_act_temp = df_act2017.merge(df_act2018, on = 'state', suffixes=('_17', '_18'))

# %%
df_act = df_act_temp.merge(df_act2019, on = 'state', suffixes=('', '_19'))

# %%
df_act_temp.head()
# Out:
#             state  act_part_17  act_eng_17  act_math_17  act_reading_17  \
# 0        Maryland         0.28        23.3         23.1            24.2
# 1          Nevada         1.00        16.3         18.0            18.1
# 2     Mississippi         1.00        18.2         18.1            18.8
# 3  South Carolina         1.00        17.5         18.6            19.1
# 4  North Carolina         1.00        17.8         19.3            19.6
#
#    act_science_17  act_composite_17  act_part_18  act_composite_18
# 0            23.8              23.6         0.31              22.5
# 1            18.2              17.8         1.00              17.7
# 2            18.8              18.6         1.00              18.6
# 3            18.9              18.7         1.00              18.3
# 4            19.3              19.1         1.00              19.1

# %%
df_act.head()
# Out:
#             state  act_part_17  act_eng_17  act_math_17  act_reading_17  \
# 0        Maryland         0.28        23.3         23.1            24.2
# 1          Nevada         1.00        16.3         18.0            18.1
# 2     Mississippi         1.00        18.2         18.1            18.8
# 3  South Carolina         1.00        17.5         18.6            19.1
# 4  North Carolina         1.00        17.8         19.3            19.6
#
#    act_science_17  act_composite_17  act_part_18  act_composite_18  act_part  \
# 0            23.8              23.6         0.31              22.5      0.28
# 1            18.2              17.8         1.00              17.7      1.00
# 2            18.8              18.6         1.00              18.6      1.00
# 3            18.9              18.7         1.00              18.3      0.78
# 4            19.3              19.1         1.00              19.1      1.00
#
#    act_composite
# 0           22.3
# 1           17.9
# ...

# %%
act_new_names_19 = {
            "act_part": "act_part_19",
            "act_composite" : "act_composite_19",
            }

df_act.rename(columns = act_new_names_19, inplace = True)

# %%
df_sat_act = df_sat.merge(df_act, how= 'left', on= 'state') #Why left merge is 154 rows, inner merge is 153 rows?
df_sat_act.head()
# Out:
#                   state  sat_part_17  sat_ebrw_17  sat_math_17  sat_total_17  \
# 0              Maryland         0.69          536          524          1060
# 1  District of Columbia         1.00          482          468           950
# 2              Delaware         1.00          503          492           996
# 3                 Idaho         0.93          513          493          1005
# 4              Michigan         1.00          509          495          1005
#
#    sat_part_18  sat_ebrw_18  sat_math_18  sat_total_18  sat_part_19  \
# 0         0.76          545          535          1080         0.82
# 1         0.92          497          480           977         0.94
# 2         1.00          505          492           998         1.00
# 3         1.00          508          493          1001         1.00
# 4         1.00          511          499          1011         1.00
#
#          ...         act_part_17  act_eng_17  act_math_17  act_reading_17  \
# ...

# %%
df_sat_act.shape
# Out:
# (52, 23)

# %%
#Remove duplicate state 'Maine'
df_sat_act.drop_duplicates(subset=['state'], inplace=True)

# %%
df_sat_act.dtypes
# Out:
# state                object
# sat_part_17         float64
# sat_ebrw_17           int64
# sat_math_17           int64
# sat_total_17          int64
# sat_part_18         float64
# sat_ebrw_18           int64
# sat_math_18           int64
# sat_total_18          int64
# sat_part_19         float64
# sat_ebrw_19           int64
# sat_math_19           int64
# sat_total_19          int64
# act_part_17         float64
# act_eng_17          float64
# act_math_17         float64
# act_reading_17      float64
# act_science_17      float64
# act_composite_17    float64
# act_part_18         float64
# act_composite_18    float64
# act_part_19         float64
# act_composite_19    float64
# dtype: object

# %%
no_of_na = df_sat_act.isna().sum()
no_of_na

#No more N/A values
# Out:
# state               0
# sat_part_17         0
# sat_ebrw_17         0
# sat_math_17         0
# sat_total_17        0
# sat_part_18         0
# sat_ebrw_18         0
# sat_math_18         0
# sat_total_18        0
# sat_part_19         0
# sat_ebrw_19         0
# sat_math_19         0
# sat_total_19        0
# act_part_17         0
# act_eng_17          0
# act_math_17         0
# act_reading_17      0
# act_science_17      0
# act_composite_17    0
# act_part_18         0
# act_composite_18    0
# act_part_19         0
# act_composite_19    0
# dtype: int64

# %% [markdown]
# ### Now for external datasets from US Census Bureau

# %% [markdown]
# #### Read in the US Census Bureau Data and clean it

# %%
df_spending_perpupil = pd.read_excel(filepath + 'US Census Bureau.xlsx', sheet_name = 'state spending per pupil')
del df_spending_perpupil['Rank**']
del df_spending_perpupil['Examine your state’s representative']

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
us_abbrev_to_state = dict([(value, key) for key, value in us_state_to_abbrev.items()])

# %%
for i in range(len(df_spending_perpupil['State'])):
    df_spending_perpupil['State'][i] = us_abbrev_to_state[df_spending_perpupil['State'][i]]
# Out:
# C:\Users\gohch\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# Median Household income in 2017 to 2019

# %%
df_household_income = pd.read_excel(filepath + 'US Census Bureau.xlsx', sheet_name = 'median household income')

# %%
df_household_income.head()
# Out:
#   State Rank States and Washington, D.C.   2019   2018   2017   2016   2015  \
# 0        NaN               United States  65712  63179  60336  57617  55775
# 1          –            Washington, D.C.  92266  85203  82372  75506  75628
# 2          1                    Maryland  86738  83242  80776  78945  75847
# 3          2               Massachusetts  85843  79835  77385  75297  70628
# 4          3                  New Jersey  85751  81740  80088  76126  72222
#
#     2014   2013   2012   2011   2010  \
# 0  53657  52250  51371  50502  50046
# 1  71648  67572  66583  63124  60903
# 2  73971  72483  71122  70004  68854
# 3  69160  66768  65339  62859  62072
# 4  71919  70165  69667  67458  67681
#
#    Average annual growth rate (current dollars) in 2010-2019, %
# 0                                             0.0307
# 1                                             0.0472
# 2                                             0.0260
# 3                                             0.0367
# ...

# %%
df_household_income = df_household_income.loc[1:,:] #Remove first row

# %%
df_household_income.dtypes
# Out:
# State Rank                                                       object
# States and Washington, D.C.                                      object
# 2019                                                              int64
# 2018                                                              int64
# 2017                                                              int64
# 2016                                                              int64
# 2015                                                              int64
# 2014                                                              int64
# 2013                                                              int64
# 2012                                                              int64
# 2011                                                              int64
# 2010                                                              int64
# Average annual growth rate (current dollars) in 2010-2019, %    float64
# dtype: object

# %%
df_household_income = df_household_income[['State Rank','States and Washington, D.C.',2017,2018,2019]]
df_household_income.rename(columns = {'State Rank': 'state_rank',
                                      'States and Washington, D.C.':'state',
                                      2017: 'hh_income_17',
                                      2018: 'hh_income_18',
                                      2019: 'hh_income_19'}, inplace = True)

# %%
df_household_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 1 to 51
# Data columns (total 5 columns):
# state_rank      51 non-null object
# state           51 non-null object
# hh_income_17    51 non-null int64
# hh_income_18    51 non-null int64
# hh_income_19    51 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_household_income.head()
# Out:
#   state_rank              state  hh_income_17  hh_income_18  hh_income_19
# 1          –   Washington, D.C.         82372         85203         92266
# 2          1           Maryland         80776         83242         86738
# 3          2      Massachusetts         77385         79835         85843
# 4          3         New Jersey         80088         81740         85751
# 5          4             Hawaii         77765         80212         83102

# %% [markdown]
# US population data

# %%
df_percapita_income = pd.read_excel(filepath + 'US Census Bureau.xlsx', sheet_name = 'per capita income')
df_percapita_income.dtypes
# Out:
# Rank                                                     float64
# State or territory                                        object
# Per capita income                                          int64
# Personal per capita income (2020)                        float64
# Of which disposable personal per capita income (2020)    float64
# Median household income (2019)                             int64
# Median family income (2019)                                int64
# Population (April 1, 2020)                                 int64
# Number of households (2019)                                int64
# Number of families (2019)                                  int64
# dtype: object

# %%
df_percapita_income.head()
# Out:
#    Rank State or territory  Per capita income  \
# 0   NaN      United States              35672
# 1   1.0   Washington, D.C.              59808
# 2   2.0      Massachusetts              46241
# 3   3.0        Connecticut              45359
# 4   4.0         New Jersey              44888
#
#    Personal per capita income (2020)  \
# 0                            59510.0
# 1                            86567.0
# 2                            78458.0
# 3                            78609.0
# 4                            73460.0
#
#    Of which disposable personal per capita income (2020)  \
# 0                                            52853.0
# 1                                            73568.0
# 2                                            66978.0
# 3                                            67110.0
# 4                                            64031.0
#
#    Median household income (2019)  Median family income (2019)  \
# ...

# %%
df_percapita_income = df_percapita_income.loc[1:,:] #Remove first row

# %%
df_percapita_income.rename(columns = {'State or territory':'state',
                            "Per capita income" : "percapita_income",
                            "Population (April 1, 2020)" : "state_pop",
                             "Number of households (2019)" : "no_of_households",
                            }, inplace = True)

# %%
df_percapita_income = df_percapita_income[["state","percapita_income","state_pop","no_of_households"]]

# %%
df_percapita_income.head()
# Out:
#                state  percapita_income  state_pop  no_of_households
# 1   Washington, D.C.             59808     689545            291570
# 2      Massachusetts             46241    7029917           2650680
# 3        Connecticut             45359    3605944           1377166
# 4         New Jersey             44888    9288294           3286264
# 5           Maryland             43325    6177224           2226767

# %%
df_us_pop = pd.read_excel(filepath + 'US Census Bureau.xlsx', sheet_name = 'US population')
df_us_pop.dtypes
# Out:
# State or Territory                                  object
# Population over the age of 25                        int64
# Population With a High School Diploma or higher      int64
# Pct With a High School Diploma or higher           float64
# Population With a Bachelor's Degree or higher        int64
# Pct With a Bachelor's Degree or higher             float64
# Population With an Advanced Degree                   int64
# Pct With an Advanced Degree                        float64
# dtype: object

# %%
df_us_pop = pd.read_excel(filepath + 'US Census Bureau.xlsx', 
                                    sheet_name = 'US population')

# %%
df_us_pop.head()
# Out:
#   State or Territory  Population over the age of 25  \
# 0            Alabama                        3360058
# 1             Alaska                         484058
# 2            Arizona                        4944540
# 3           Arkansas                        2036456
# 4         California                       26937872
#
#    Population With a High School Diploma or higher  \
# 0                                          2926985
# 1                                           452968
# 2                                          4331542
# 3                                          1781463
# 4                                         22636359
#
#    Pct With a High School Diploma or higher  \
# 0                                    0.8711
# 1                                    0.9358
# 2                                    0.8760
# 3                                    0.8748
# 4                                    0.8403
#
#    Population With a Bachelor's Degree or higher  \
# ...

# %%
df_us_pop.rename(columns = {'State or Territory':'state',
                            "Pct With a High School Diploma or higher" : "pct_highschool",
                            "Pct With a Bachelor's Degree or higher" : "pct_bachelors",
                            "Pct With an Advanced Degree" : "pct_adv_degree",
                            "Population With a High School Diploma or higher" : "pop_highschool",
                            "Population With a Bachelor's Degree or higher" : "pop_bachelors",
                            "Population With an Advanced Degree" : "pop_adv_degree"
                            }, inplace = True)

df_us_pop = df_us_pop[['state', 'pct_highschool','pct_bachelors','pct_adv_degree',
                       'pop_highschool','pop_bachelors','pop_adv_degree']]

# %%
df_us_pop.head()
# Out:
#          state  pct_highschool  pct_bachelors  pct_adv_degree  pop_highschool  \
# 0      Alabama          0.8711         0.2635          0.1004         2926985
# 1       Alaska          0.9358         0.3019          0.1169          452968
# 2      Arizona          0.8760         0.3018          0.1135         4331542
# 3     Arkansas          0.8748         0.2334          0.0826         1781463
# 4   California          0.8403         0.3500          0.1314        22636359
#
#    pop_bachelors  pop_adv_degree
# 0         885357          337382
# 1         146157           56574
# 2        1492158          561120
# 3         475367          168182
# 4        9428484         3538760

# %%
df_spending_perpupil.rename(columns = {'State': 'state', 'Spending per pupil ($’s)':'statespending_perpupil'}, inplace = True)

# %%
df_spending_perpupil.head()
# Out:
#                   state  statespending_perpupil
# 0              New York                   20645
# 1               Wyoming                   19238
# 2            New Jersey                   18874
# 3  District of Columbia                   18069
# 4           Connecticut                   17373

# %%
df_spending_perpupil.dtypes
# Out:
# state                     object
# statespending_perpupil     int64
# dtype: object

# %%
df_spending_perpupil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 2 columns):
# state                     51 non-null object
# statespending_perpupil    51 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 896.0+ bytes

# %% [markdown]
# Merge all US income and spending external datasets into 2 dataframes.

# %%
# Merge all these admin datasets into one.
df_us_combined1 = df_household_income.merge(df_percapita_income, how= 'left', on=['state'])
df_us_combined1.head()
# Out:
#   state_rank              state  hh_income_17  hh_income_18  hh_income_19  \
# 0          –   Washington, D.C.         82372         85203         92266
# 1          1           Maryland         80776         83242         86738
# 2          2      Massachusetts         77385         79835         85843
# 3          3         New Jersey         80088         81740         85751
# 4          4             Hawaii         77765         80212         83102
#
#    percapita_income  state_pop  no_of_households
# 0             59808     689545            291570
# 1             43325    6177224           2226767
# 2             46241    7029917           2650680
# 3             44888    9288294           3286264
# 4             36989    1455271            465299

# %%
df_us_combined2 = df_us_combined1.merge(df_us_pop, how= 'left', on=['state'])
df_us_combined2.head()
# Out:
#   state_rank              state  hh_income_17  hh_income_18  hh_income_19  \
# 0          –   Washington, D.C.         82372         85203         92266
# 1          1           Maryland         80776         83242         86738
# 2          2      Massachusetts         77385         79835         85843
# 3          3         New Jersey         80088         81740         85751
# 4          4             Hawaii         77765         80212         83102
#
#    percapita_income  state_pop  no_of_households  pct_highschool  \
# 0             59808     689545            291570             NaN
# 1             43325    6177224           2226767          0.9039
# 2             46241    7029917           2650680          0.9132
# 3             44888    9288294           3286264          0.9032
# 4             36989    1455271            465299          0.9238
#
#    pct_bachelors  pct_adv_degree  pop_highschool  pop_bachelors  \
# ...

# %%
#Rename Washington, D.C. to 'District of Columbia'
df_us_combined1['state'] = df_us_combined1['state'].map(lambda x: x.replace('Washington, D.C.', 'District of Columbia'))

# %%
df_us_combined2 = df_us_combined1.merge(df_us_pop, how= 'left', on=['state'])
df_us_combined2.head()
#settled
# Out:
#   state_rank                  state  hh_income_17  hh_income_18  hh_income_19  \
# 0          –   District of Columbia         82372         85203         92266
# 1          1               Maryland         80776         83242         86738
# 2          2          Massachusetts         77385         79835         85843
# 3          3             New Jersey         80088         81740         85751
# 4          4                 Hawaii         77765         80212         83102
#
#    percapita_income  state_pop  no_of_households  pct_highschool  \
# 0             59808     689545            291570          0.9185
# 1             43325    6177224           2226767          0.9039
# 2             46241    7029917           2650680          0.9132
# 3             44888    9288294           3286264          0.9032
# 4             36989    1455271            465299          0.9238
#
#    pct_bachelors  pct_adv_degree  pop_highschool  pop_bachelors  \
# ...

# %%
df_us_combined3 = df_us_combined2.merge(df_spending_perpupil, how= 'left', on=['state'])
df_us_combined3.head()
# Out:
#   state_rank                  state  hh_income_17  hh_income_18  hh_income_19  \
# 0          –   District of Columbia         82372         85203         92266
# 1          1               Maryland         80776         83242         86738
# 2          2          Massachusetts         77385         79835         85843
# 3          3             New Jersey         80088         81740         85751
# 4          4                 Hawaii         77765         80212         83102
#
#    percapita_income  state_pop  no_of_households  pct_highschool  \
# 0             59808     689545            291570          0.9185
# 1             43325    6177224           2226767          0.9039
# 2             46241    7029917           2650680          0.9132
# 3             44888    9288294           3286264          0.9032
# 4             36989    1455271            465299          0.9238
#
#    pct_bachelors  pct_adv_degree  pop_highschool  pop_bachelors  \
# ...

# %%
df_us_combined3.info() #Check why statespending_perpupil is not showing
#It is because the state in the Excel has leading spaces. One way is to strip all the spaces in the state and make it uniform.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 15 columns):
# state_rank                51 non-null object
# state                     51 non-null object
# hh_income_17              51 non-null int64
# hh_income_18              51 non-null int64
# hh_income_19              51 non-null int64
# percapita_income          51 non-null int64
# state_pop                 51 non-null int64
# no_of_households          51 non-null int64
# pct_highschool            51 non-null float64
# pct_bachelors             51 non-null float64
# pct_adv_degree            51 non-null float64
# pop_highschool            51 non-null int64
# pop_bachelors             51 non-null int64
# pop_adv_degree            51 non-null int64
# statespending_perpupil    0 non-null float64
# dtypes: float64(4), int64(9), object(2)
# memory usage: 6.4+ KB

# %%
df_us_combined2['state'] = df_us_combined2['state'].map(lambda x: x.replace(' ', '').replace(u'\xa0', u''))
df_us_combined2.head()
# Out:
#   state_rank               state  hh_income_17  hh_income_18  hh_income_19  \
# 0          –  DistrictofColumbia         82372         85203         92266
# 1          1            Maryland         80776         83242         86738
# 2          2       Massachusetts         77385         79835         85843
# 3          3           NewJersey         80088         81740         85751
# 4          4              Hawaii         77765         80212         83102
#
#    percapita_income  state_pop  no_of_households  pct_highschool  \
# 0             59808     689545            291570          0.9185
# 1             43325    6177224           2226767          0.9039
# 2             46241    7029917           2650680          0.9132
# 3             44888    9288294           3286264          0.9032
# 4             36989    1455271            465299          0.9238
#
#    pct_bachelors  pct_adv_degree  pop_highschool  pop_bachelors  \
# ...

# %%
#Do the same to remove spaces from State column in the other dataset
df_spending_perpupil['state'] = df_spending_perpupil['state'].map(lambda x: x.replace(' ', ''))
df_spending_perpupil['state'].head()
# Out:
# 0               NewYork
# 1               Wyoming
# 2             NewJersey
# 3    DistrictofColumbia
# 4           Connecticut
# Name: state, dtype: object

# %%
df_us_combined3 = df_us_combined2.merge(df_spending_perpupil, how= 'left', on=['state'])
df_us_combined3.head()
# Out:
#   state_rank               state  hh_income_17  hh_income_18  hh_income_19  \
# 0          –  DistrictofColumbia         82372         85203         92266
# 1          1            Maryland         80776         83242         86738
# 2          2       Massachusetts         77385         79835         85843
# 3          3           NewJersey         80088         81740         85751
# 4          4              Hawaii         77765         80212         83102
#
#    percapita_income  state_pop  no_of_households  pct_highschool  \
# 0             59808     689545            291570          0.9185
# 1             43325    6177224           2226767          0.9039
# 2             46241    7029917           2650680          0.9132
# 3             44888    9288294           3286264          0.9032
# 4             36989    1455271            465299          0.9238
#
#    pct_bachelors  pct_adv_degree  pop_highschool  pop_bachelors  \
# ...

# %%
df_sat_act['state'] = df_sat_act['state'].map(lambda x: x.replace(' ', ''))

# %%
df_us_sat_act = df_sat_act.merge(df_us_combined3, how= 'left', on= 'state') 
#Column UnitedStates is removed during this left merge

# %%
df_us_sat_act.dtypes
# Out:
# state                      object
# sat_part_17               float64
# sat_ebrw_17                 int64
# sat_math_17                 int64
# sat_total_17                int64
# sat_part_18               float64
# sat_ebrw_18                 int64
# sat_math_18                 int64
# sat_total_18                int64
# sat_part_19               float64
# sat_ebrw_19                 int64
# sat_math_19                 int64
# sat_total_19                int64
# act_part_17               float64
# act_eng_17                float64
# act_math_17               float64
# act_reading_17            float64
# act_science_17            float64
# act_composite_17          float64
# act_part_18               float64
# act_composite_18          float64
# act_part_19               float64
# act_composite_19          float64
# state_rank                 object
# hh_income_17                int64
# hh_income_18                int64
# hh_income_19                int64
# ...

# %%
df_us_sat_act.shape
# Out:
# (51, 37)

# %%
df_us_sat_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 37 columns):
# state                     51 non-null object
# sat_part_17               51 non-null float64
# sat_ebrw_17               51 non-null int64
# sat_math_17               51 non-null int64
# sat_total_17              51 non-null int64
# sat_part_18               51 non-null float64
# sat_ebrw_18               51 non-null int64
# sat_math_18               51 non-null int64
# sat_total_18              51 non-null int64
# sat_part_19               51 non-null float64
# sat_ebrw_19               51 non-null int64
# sat_math_19               51 non-null int64
# sat_total_19              51 non-null int64
# act_part_17               51 non-null float64
# act_eng_17                51 non-null float64
# act_math_17               51 non-null float64
# act_reading_17            51 non-null float64
# act_science_17            51 non-null float64
# ...

# %% [markdown]
# Adding variables for state policies of whether SAT/ACT is required or offered free

# %%
# To do: add dummy variables for the state policies
states_act_required = ['Alabama' , 'Hawaii', 'Montana', 'Nebraska', 'NorthCarolina', 'NorthDakota', 'Wisconsin',
                       'Kentucky', 'Louisiana', 'Mississippi', 'Utah' , 'Wyoming']

states_sat_required = ['Colorado', 'Connecticut', 'Delaware', 'Illinois', 'Michigan', 
                       'New Hampshire', 'RhodeIsland', 'WestVirginia']

states_act_free = ['Alabama' , 'Hawaii', 'Montana', 'Nebraska', 'NorthCarolina', 'NorthDakota', 'Wisconsin',
                       'Kentucky', 'Louisiana', 'Mississippi', 'Utah' , 'Wyoming', 'Arkansas', 'Kansas']

states_sat_free = ['DistrictofColumbia', 'Idaho', 'Maine', 'Tennessee', 'Ohio', 'Oklahoma', 'SouthCarolina']

sat_or_act_offered = ['Minnesota', 'Ohio', 'Oklahoma', 'South Carolina', 'Temmessee']

# %%
df_us_sat_act['is_act_free'] = np.where(df_us_sat_act['state'].isin(states_act_free), True, False)
df_us_sat_act['is_sat_free'] = np.where(df_us_sat_act['state'].isin(states_sat_free), True, False)
df_us_sat_act['is_act_required'] = np.where(df_us_sat_act['state'].isin(states_act_required), True, False)
df_us_sat_act['is_sat_required'] = np.where(df_us_sat_act['state'].isin(states_sat_required), True, False)

# %%
df_us_sat_act[['state','is_act_free','is_sat_free','is_act_required','is_sat_required']].head()
# Out:
#                 state  is_act_free  is_sat_free  is_act_required  \
# 0            Maryland        False        False            False
# 1  DistrictofColumbia        False         True            False
# 2            Delaware        False        False            False
# 3               Idaho        False         True            False
# 4            Michigan        False        False            False
#
#    is_sat_required
# 0            False
# 1            False
# 2             True
# 3            False
# 4             True

# %% [markdown]
# Save cleaned and merged dataframes as csv files.

# %%
df_us_sat_act.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 41 columns):
# state                     51 non-null object
# sat_part_17               51 non-null float64
# sat_ebrw_17               51 non-null int64
# sat_math_17               51 non-null int64
# sat_total_17              51 non-null int64
# sat_part_18               51 non-null float64
# sat_ebrw_18               51 non-null int64
# sat_math_18               51 non-null int64
# sat_total_18              51 non-null int64
# sat_part_19               51 non-null float64
# sat_ebrw_19               51 non-null int64
# sat_math_19               51 non-null int64
# sat_total_19              51 non-null int64
# act_part_17               51 non-null float64
# act_eng_17                51 non-null float64
# act_math_17               51 non-null float64
# act_reading_17            51 non-null float64
# act_science_17            51 non-null float64
# ...

# %% [markdown]
# ## Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |	state	|	*object*	|	df_us_sat_act	|	Name of the U.S. state or district	|
# |	sat_part_17	|	*float* |	df_us_sat_act	|	SAT 2017 participation rate	(units percent to two decimal places i.e. 1.00 means 100%)|
# |	sat_ebrw_17	|*integer*|	df_us_sat_act	|	SAT 2017 Evidence-Based Reading and Writing average score for each state	|
# |	sat_math_17	|*integer*|	df_us_sat_act	|	SAT 2017 Math average score for each state	|
# |	sat_total_17	|*integer*|	df_us_sat_act	|	SAT 2017 Total average score for each state	|
# |	sat_part_18	|	*float*	|	df_us_sat_act	|	SAT 2018 participation rate	(units percent to two decimal places i.e. 1.00 means 100%)|
# |	sat_ebrw_18	|*integer*|	df_us_sat_act	|	SAT 2018 Evidence-Based Reading and Writing average score for each state	|
# |	sat_math_18	|*integer*|	df_us_sat_act	|	SAT 2018 Math average score for each state	|
# |	sat_total_18	|*integer*|	df_us_sat_act	|	SAT 2018 Total average score for each state	|
# |	sat_part_19	|	*float*	|	df_us_sat_act	|	SAT 2019 participation rate	(units percent to two decimal places i.e. 1.00 means 100%)|
# |	sat_ebrw_19	|*integer*	|	df_us_sat_act	|	SAT 2019 Evidence-Based Reading and Writing average score for each state	|
# |	sat_math_19	|*integer*|	df_us_sat_act	|	SAT 2019 Math average score for each state	|
# |	sat_total_19	|*integer*|	df_us_sat_act	|	SAT 2019 Total average score for each state	|
# |	act_part_17	|	*float*	|	df_us_sat_act	|	ACT 2017 Math average score for each state	(units percent to two decimal places i.e. 1.00 means 100%)|
# |	act_eng_17	|	*float*	|	df_us_sat_act	|	ACT 2017 Math average score for each state	|
# |	act_math_17	|	*float*	|	df_us_sat_act	|	ACT 2017 Math average score for each state	|
# |	act_reading_17	|	*float*	|	df_us_sat_act	|	ACT 2017 Math average score for each state	|
# |	act_science_17	|	*float*	|	df_us_sat_act	|	ACT 2017 Math average score for each state	|
# |	act_composite_17	|	*float*	|	df_us_sat_act	|	ACT 2017 Math average score for each state	|
# |	act_part_18	|	*float* |	df_us_sat_act	|	ACT 2018 participation rate	(units percent to two decimal places i.e. 1.00 means 100%)|
# |	act_composite_18	|	*float*	|	df_us_sat_act	|	ACT 2018 average composite score	|
# |	act_part_19	|	*float*	|	df_us_sat_act	|	ACT 2019 participation rate	(units percent to two decimal places i.e. 1.00 means 100%)|
# |	act_composite_19	|	*float*	|	df_us_sat_act	|	ACT 2019 average composite score	|
# |	state_rank	|	object	|	df_us_sat_act	|	State rank of mean household income based on US Census Bureau	|
# |	hh_income_17	|*integer*|	df_us_sat_act	|	Mean household income per state in 2017	(units in USD)|
# |	hh_income_18	|*integer*|	df_us_sat_act	|	Mean household income per state in 2018	(units in USD)|
# |	hh_income_19	|*integer*|	df_us_sat_act	|	Mean household income per state in 2019	(units in USD)|
# |	percapita_income	|	*float*	|	df_us_sat_act	|	Mean per capita income in 2020 based on US Census Bureau	|
# |	state_pop	|	*float*	|	df_us_sat_act	|	State population 2020 based on US Census Bureau	|
# |	no_of_households	|	*float*	|	df_us_sat_act	|	No of households in each state	|
# |	pct_highschool	|	*float*	|	df_us_sat_act	|	Percentage of population with at least High school diploma	|
# |	pct_bachelors	|	*float*	|	df_us_sat_act	|	Percentage of population with at least Bachelor's degree	|
# |	pct_adv_degree	|	*float*	|	df_us_sat_act	|	Percentage of population with an advanced degree and above	|
# |	pop_highschool	|*integer*|	df_us_sat_act	|	State population that has at least a High school diploma	|
# |	pop_bachelors	|*integer*|	df_us_sat_act	|	State population that has at least a Bachelor's degree	|
# |	pop_adv_degree	|*integer*|	df_us_sat_act	|	State population that has an advanced degree and above	|
# |	statespending_perpupil	|	*float*	|	df_us_sat_act	|	2020 State spending on education (units in USD)|
# |	is_sat_free	|	*boolean*	|	df_us_sat_act	|	Whether SAT is provided free of charge in the state as of 2020 |
# |	is_act_free	|	*boolean*	|	df_us_sat_act	|	Whether ACT is provided free of charge in the state as of 2020 |
# |	is_sat_required	|	*boolean*	|	df_us_sat_act	|	Whether SAT is required in the state as of 2020 |
# |	is_act_required	|	*boolean*	|	df_us_sat_act	|	Whether ACT is required in the state as of 2020 |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %% [markdown]
# #### Summary statistics

# %%
df_us_sat_act.describe()
# Out:
#        sat_part_17  sat_ebrw_17  sat_math_17  sat_total_17  sat_part_18  \
# count    51.000000    51.000000    51.000000     51.000000    51.000000
# mean      0.398039   569.117647   556.882353   1126.098039     0.457451
# std       0.352766    45.666901    47.121395     92.494812     0.373143
# min       0.020000   482.000000   468.000000    950.000000     0.020000
# 25%       0.040000   533.500000   523.500000   1055.500000     0.045000
# 50%       0.380000   559.000000   548.000000   1107.000000     0.520000
# 75%       0.660000   613.000000   599.000000   1212.000000     0.775000
# max       1.000000   644.000000   651.000000   1295.000000     1.000000
#
#        sat_ebrw_18  sat_math_18  sat_total_18  sat_part_19  sat_ebrw_19  \
# count    51.000000    51.000000     51.000000    51.000000    51.000000
# mean    563.686275   556.235294   1120.019608     0.490588   560.803922
# std      47.502627    47.772623     94.155083     0.387476    46.248035
# ...

# %% [markdown]
# #### Apply standard deviation using function calculate_sd using list comprehension

# %% [markdown]
# Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.

# %%
# Dictionary comprehension to apply std to each numeric column in the dataframe. 

sd = {col: round(calculate_sd(df_us_sat_act[col]),2) for col in df_us_sat_act.columns if ((df_us_sat_act[col].dtype == float) | (df_us_sat_act[col].dtype == 'int64'))} 
sd
# Out:
# {'act_composite_17': 2.0,
#  'act_composite_18': 2.09,
#  'act_composite_19': 2.17,
#  'act_eng_17': 2.33,
#  'act_math_17': 1.96,
#  'act_part_17': 0.32,
#  'act_part_18': 0.34,
#  'act_part_19': 0.34,
#  'act_reading_17': 2.05,
#  'act_science_17': 1.74,
#  'hh_income_17': 10124.31,
#  'hh_income_18': 10507.25,
#  'hh_income_19': 11061.28,
#  'no_of_households': 2547001.27,
#  'pct_adv_degree': 0.04,
#  'pct_bachelors': 0.06,
#  'pct_highschool': 0.03,
#  'percapita_income': 6015.52,
#  'pop_adv_degree': 653936.36,
#  'pop_bachelors': 1699833.7,
#  'pop_highschool': 4252418.01,
#  'sat_ebrw_17': 45.22,
#  'sat_ebrw_18': 47.03,
#  'sat_ebrw_19': 45.79,
#  'sat_math_17': 46.66,
#  'sat_math_18': 47.3,
#  'sat_math_19': 50.79,
#  'sat_part_17': 0.35,
#  'sat_part_18': 0.37,
#  'sat_part_19': 0.38,
#  'sat_total_17': 91.58,
#  'sat_total_18': 93.23,
#  'sat_total_19': 96.24,
#  'state_pop': 7335030.1,
#  'statespending_perpupil': 3014.14}

# %% [markdown]
# #### Investigate trends in the data.

# %% [markdown]
# Q: Do any states have >50% participation on *both* tests each year?

# %%
new_names = {'act_part_17': 2017,
            'act_part_18' : 2018,
            'act_part_19' : 2019,
            'sat_part_17': 2017,
            'sat_part_18' : 2018,
            'sat_part_19' : 2019}

# %%
df_participation_act = df_us_sat_act[['state', 'act_part_17', 'act_part_18', 'act_part_19']].rename(columns = new_names)
df_participation_act = pd.melt(df_participation_act, id_vars=['state'], value_vars=[2017,2018,2019],
                          var_name='year', value_name='act_part')
df_participation_act.head()
# Out:
#                 state  year  act_part
# 0            Maryland  2017      0.28
# 1  DistrictofColumbia  2017      0.32
# 2            Delaware  2017      0.18
# 3               Idaho  2017      0.38
# 4            Michigan  2017      0.29

# %%
df_participation_sat = df_us_sat_act[['state', 'sat_part_17', 'sat_part_18', 'sat_part_19']].rename(columns = new_names)
df_participation_sat = pd.melt(df_participation_sat, id_vars=['state'], value_vars=[2017,2018,2019],
                          var_name='year', value_name='sat_part')
df_participation_sat.head()
# Out:
#                 state  year  sat_part
# 0            Maryland  2017      0.69
# 1  DistrictofColumbia  2017      1.00
# 2            Delaware  2017      1.00
# 3               Idaho  2017      0.93
# 4            Michigan  2017      1.00

# %%
df_temp = df_participation_act.merge(df_participation_sat, on =['state','year'])
df_temp.head()
# Out:
#                 state  year  act_part  sat_part
# 0            Maryland  2017      0.28      0.69
# 1  DistrictofColumbia  2017      0.32      1.00
# 2            Delaware  2017      0.18      1.00
# 3               Idaho  2017      0.38      0.93
# 4            Michigan  2017      0.29      1.00

# %%
df_sorted = df_temp[(df_temp['sat_part'] > 0.5) & (df_temp['act_part'] > 0.5)]

# %%
df_sorted = df_sorted.sort_values(by ='state')
df_sorted
# Out:
#              state  year  act_part  sat_part
# 5          Florida  2017      0.73      0.83
# 56         Florida  2018      0.66      0.56
# 107        Florida  2019      0.54      1.00
# 9          Georgia  2017      0.55      0.61
# 60         Georgia  2018      0.53      0.70
# 24          Hawaii  2017      0.90      0.55
# 75          Hawaii  2018      0.89      0.56
# 126         Hawaii  2019      0.80      0.54
# 73   NorthCarolina  2018      1.00      0.52
# 124  NorthCarolina  2019      1.00      0.51
# 63   SouthCarolina  2018      1.00      0.55
# 114  SouthCarolina  2019      0.78      0.68

# %% [markdown]
# Observation
#
# The following states had >50% participation on *both* tests each year:
# - Florida
# - Hawaii
#
# However these 2 states are very different. Florida seems to be switching from ACT to SAT as the main assessment (ACT decreasing and SAT increasing to reach 100%), wherease Hawaii participation rates remain roughly constant throughout the years.
#
# The following states only had >50% participation on both tests for 2 out of 3 years:
# - Georgia
# - North Carolina
# - South Carolina

# %% [markdown]
# Q: Which states have the highest and lowest participation rates for the 2019 SAT and ACT? How does that relate to the SAT or ACT state policy of whether it is free and/or required?

# %%
#ACT Participation rates 2019 X Whether ACT Free X Whether ACT Required
df_act_2019 = df_us_sat_act.sort_values(['act_part_19'], ascending=True).reset_index(drop=True) 
lowest_act_part_2019 = {df_act_2019['state'][i]: [df_act_2019['act_part_19'][i], df_act_2019['is_act_free'][i], df_act_2019['is_act_required'][i]] for i in range(5)} 
print(f'Lowest ACT participation states in 2019: \n {lowest_act_part_2019} \n')


highest_act_part_2019 ={df_act_2019['state'][i]: [df_act_2019['act_part_19'][i], df_act_2019['is_act_free'][i], df_act_2019['is_act_required'][i]] for i in range(len(df_act_2019)) if df_act_2019['act_part_19'][i]== 1}
print(f'Highest ACT participation states in 2019: \n {highest_act_part_2019} \n')
# Out:
# Lowest ACT participation states in 2019:
#  {'Maine': [0.06, False, False], 'RhodeIsland': [0.12, False, False], 'Delaware': [0.13, False, False], 'NewHampshire': [0.14, False, False], 'Pennsylvania': [0.17, False, False]}
#
# Highest ACT participation states in 2019:
#  {'Montana': [1.0, True, True], 'NorthCarolina': [1.0, True, True], 'Alabama': [1.0, True, True], 'Ohio': [1.0, False, False], 'Tennessee': [1.0, False, False], 'Wyoming': [1.0, True, True], 'Mississippi': [1.0, True, True], 'Utah': [1.0, True, True], 'Kentucky': [1.0, True, True], 'Nebraska': [1.0, True, True], 'Nevada': [1.0, False, False], 'Oklahoma': [1.0, False, False], 'Wisconsin': [1.0, True, True], 'Louisiana': [1.0, True, True], 'Arkansas': [1.0, True, False]}

# %%
#SAT Participation rates 2019 X Whether SAT Free X Whether SAT Required
df_sat_2019 = df_us_sat_act.sort_values(['sat_part_19'], ascending=True).reset_index(drop=True) 
lowest_sat_part_2019 = {df_sat_2019['state'][i]: [df_sat_2019['sat_part_19'][i], df_sat_2019['is_sat_free'][i], df_sat_2019['is_sat_required'][i]] for i in range(5)} 
print(f'Lowest SAT participation states in 2019: \n {lowest_sat_part_2019}\n')

highest_sat_part_2019 ={df_sat_2019['state'][i]: [df_sat_2019['sat_part_19'][i], df_sat_2019['is_sat_free'][i], df_sat_2019['is_sat_required'][i]] for i in range(len(df_sat_2019)) if df_sat_2019['sat_part_19'][i]== 1}
print(f'\nHighest SAT participation states in 2019: \n {highest_sat_part_2019}')
# Out:
# Lowest SAT participation states in 2019:
#  {'NorthDakota': [0.02, False, False], 'Wisconsin': [0.03, False, False], 'Iowa': [0.03, False, False], 'SouthDakota': [0.03, False, False], 'Wyoming': [0.03, False, False]}
#
#
# Highest SAT participation states in 2019:
#  {'Connecticut': [1.0, False, True], 'Illinois': [1.0, False, True], 'Florida': [1.0, False, False], 'Michigan': [1.0, False, True], 'Idaho': [1.0, True, False], 'Delaware': [1.0, False, True], 'RhodeIsland': [1.0, False, True], 'Colorado': [1.0, False, True]}

# %% [markdown]
# - Which states have the highest and lowest mean total/composite scores for the 2019 SAT and ACT? How does that relate to the SAT or ACT state policy of whether it is free and/or required?

# %%
# ACT Composite scores 2019 X Whether ACT free X Whether ACT Required
df_act19 = df_us_sat_act.sort_values(['act_composite_19'], ascending=True).reset_index(drop=True) 
lowest_act_total_2019 = {df_act19['state'][i]: [df_act19['act_composite_19'][i], df_act19['is_act_free'][i], df_act19['is_act_required'][i]] for i in range(5)} 
print(f'Lowest ACT Composite Scores in 2019: \n {lowest_act_total_2019}')

df_act19 = df_us_sat_act.sort_values(['act_composite_19'], ascending=False).reset_index(drop=True) 
highest_act_total_2019 = {df_act19['state'][i]: [df_act19['act_composite_19'][i], df_act19['is_act_free'][i], df_act19['is_act_required'][i]] for i in range(5)} 
print(f'\nHighest ACT Composite Scores in 2019: \n {highest_act_total_2019}')
# Out:
# Lowest ACT Composite Scores in 2019:
#  {'Nevada': [17.9, False, False], 'Mississippi': [18.4, True, True], 'Louisiana': [18.8, True, True], 'SouthCarolina': [18.8, False, False], 'Alabama': [18.9, True, True]}
#
# Highest ACT Composite Scores in 2019:
#  {'Massachusetts': [25.5, False, False], 'Connecticut': [25.5, False, False], 'NewHampshire': [25.0, False, False], 'RhodeIsland': [24.7, False, False], 'NewYork': [24.5, False, False]}

# %%
#SAT Total scores 2019 X Whether SAT Free X Whether SAT Required
df_sat19 = df_us_sat_act.sort_values(['sat_total_19'], ascending=True).reset_index(drop=True) 
lowest_sat_total_2019 = {df_sat19['state'][i]: [df_sat19['sat_total_19'][i], df_sat19['is_sat_free'][i], df_sat19['is_sat_required'][i]] for i in range(5)} 
print(f'Lowest SAT Total Scores in 2019: \n {lowest_sat_total_2019}')

df_sat19 = df_us_sat_act.sort_values(['sat_total_19'], ascending=False).reset_index(drop=True)
highest_sat_total_2019 = {df_sat19['state'][i]: [df_sat19['sat_total_19'][i], df_sat19['is_sat_free'][i], df_sat19['is_sat_required'][i]] for i in range(5)} 
print(f'\nHighest SAT Total Scores in 2019: \n {highest_sat_total_2019}')
# Out:
# Lowest SAT Total Scores in 2019:
#  {'WestVirginia': [943, False, True], 'Oklahoma': [963, True, False], 'DistrictofColumbia': [975, True, False], 'Delaware': [985, False, True], 'Idaho': [993, True, False]}
#
# Highest SAT Total Scores in 2019:
#  {'Minnesota': [1284, False, False], 'Wisconsin': [1283, False, False], 'SouthDakota': [1268, False, False], 'NorthDakota': [1263, False, False], 'Nebraska': [1260, False, False]}

# %%
# Total scores X SAT requirement
df_sat19 = df_us_sat_act.sort_values(['sat_total_19'], ascending=True).reset_index(drop=True) 
lowest_sat_total_2019 = {df_sat19['state'][i]: [df_sat19['sat_total_19'][i], df_sat19['is_sat_required'][i]] for i in range(5)} 
print(f'Lowest SAT Total Scores in 2019: \n {lowest_sat_total_2019}')

df_sat19 = df_us_sat_act.sort_values(['sat_total_19'], ascending=False).reset_index(drop=True)
highest_sat_total_2019 = {df_sat19['state'][i]: [df_sat19['sat_total_19'][i], df_sat19['is_sat_required'][i]] for i in range(5)} 
print(f'\nHighest SAT Total Scores in 2019: \n {highest_sat_total_2019}')
# Out:
# Lowest SAT Total Scores in 2019:
#  {'WestVirginia': [943, True], 'Oklahoma': [963, False], 'DistrictofColumbia': [975, False], 'Delaware': [985, True], 'Idaho': [993, False]}
#
# Highest SAT Total Scores in 2019:
#  {'Minnesota': [1284, False], 'Wisconsin': [1283, False], 'SouthDakota': [1268, False], 'NorthDakota': [1263, False], 'Nebraska': [1260, False]}

# %%
df_us_sat_act.groupby('is_sat_free').mean().T
# Out:
# is_sat_free                    False         True
# sat_part_17             3.790909e-01  5.171429e-01
# sat_ebrw_17             5.737045e+02  5.402857e+02
# sat_math_17             5.620227e+02  5.245714e+02
# sat_total_17            1.135818e+03  1.065000e+03
# sat_part_18             4.443182e-01  5.400000e-01
# sat_ebrw_18             5.674318e+02  5.401429e+02
# sat_math_18             5.612727e+02  5.245714e+02
# sat_total_18            1.128818e+03  1.064714e+03
# sat_part_19             4.756818e-01  5.842857e-01
# sat_ebrw_19             5.660227e+02  5.280000e+02
# sat_math_19             5.583182e+02  5.137143e+02
# sat_total_19            1.124455e+03  1.041571e+03
# act_part_17             6.534091e-01  6.471429e-01
# act_eng_17              2.091591e+01  2.102857e+01
# act_math_17             2.120000e+01  2.107143e+01
# act_reading_17          2.200455e+01  2.207143e+01
# act_science_17          2.147500e+01  2.138571e+01
# ...

# %%
df_us_sat_act.groupby('is_sat_required').mean().T
# Out:
# is_sat_required                False         True
# sat_part_17             3.693182e-01  5.785714e-01
# sat_ebrw_17             5.732045e+02  5.434286e+02
# sat_math_17             5.613409e+02  5.288571e+02
# sat_total_17            1.134659e+03  1.072286e+03
# sat_part_18             3.884091e-01  8.914286e-01
# sat_ebrw_18             5.713409e+02  5.155714e+02
# sat_math_18             5.648864e+02  5.018571e+02
# sat_total_18            1.136318e+03  1.017571e+03
# sat_part_19             4.097727e-01  9.985714e-01
# sat_ebrw_19             5.693864e+02  5.068571e+02
# sat_math_19             5.614091e+02  4.942857e+02
# sat_total_19            1.130864e+03  1.001286e+03
# act_part_17             6.743182e-01  5.157143e-01
# act_eng_17              2.065227e+01  2.268571e+01
# act_math_17             2.100909e+01  2.227143e+01
# act_reading_17          2.179773e+01  2.337143e+01
# act_science_17          2.128409e+01  2.258571e+01
# ...

# %%
df_us_sat_act.groupby('is_act_free').mean().T
# Out:
# is_act_free                    False         True
# sat_part_17             5.081081e-01  1.071429e-01
# sat_ebrw_17             5.529459e+02  6.118571e+02
# sat_math_17             5.410270e+02  5.987857e+02
# sat_total_17            1.094081e+03  1.210714e+03
# sat_part_18             5.875676e-01  1.135714e-01
# sat_ebrw_18             5.510811e+02  5.970000e+02
# sat_math_18             5.414054e+02  5.954286e+02
# sat_total_18            1.092568e+03  1.192571e+03
# sat_part_19             6.335135e-01  1.128571e-01
# sat_ebrw_19             5.439459e+02  6.053571e+02
# sat_math_19             5.343784e+02  5.992857e+02
# sat_total_19            1.078378e+03  1.204786e+03
# act_part_17             5.359459e-01  9.607143e-01
# act_eng_17              2.157568e+01  1.922857e+01
# act_math_17             2.176216e+01  1.965000e+01
# act_reading_17          2.263514e+01  2.037143e+01
# act_science_17          2.195135e+01  2.017143e+01
# ...

# %%
df_us_sat_act.groupby('is_act_required').mean().T
# Out:
# is_act_required                False         True
# sat_part_17             4.838462e-01  1.191667e-01
# sat_ebrw_17             5.565385e+02  6.100000e+02
# sat_math_17             5.446154e+02  5.967500e+02
# sat_total_17            1.101256e+03  1.206833e+03
# sat_part_18             5.597436e-01  1.250000e-01
# sat_ebrw_18             5.542308e+02  5.944167e+02
# sat_math_18             5.445897e+02  5.940833e+02
# sat_total_18            1.098949e+03  1.188500e+03
# sat_part_19             6.035897e-01  1.233333e-01
# sat_ebrw_19             5.468205e+02  6.062500e+02
# sat_math_19             5.372821e+02  6.006667e+02
# sat_total_19            1.084154e+03  1.207083e+03
# act_part_17             5.528205e-01  9.766667e-01
# act_eng_17              2.149487e+01  1.910000e+01
# act_math_17             2.167949e+01  1.956667e+01
# act_reading_17          2.255128e+01  2.026667e+01
# act_science_17          2.188205e+01  2.010000e+01
# ...

# %%
# Visualise correlation between SAT participation and statespending_perpupil
df_satpart_spending = df_us_sat_act[['sat_']]

plt.figure(figsize=(10,10))
mask = np.zeros_like(df_sat_act_2017.corr()) 
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    sns.heatmap(df_sat_act_2017.corr(), mask = mask, annot = True, square = True, vmin = -1, vmax = 1, 
                linewidths = 1)

# %%
#draw the boxplots of statespending_perpupil, show how that correlates to ACT and SAT free 
sns.boxplot(df_us_sat_act.statespending_perpupil);

# %% [markdown]
# The point with the outlier for state spending on education per pupil is New York. SAT and ACT are not free in this state.

# %%
sns.boxplot(df_us_sat_act.pct_bachelors);

# %% [markdown]
# The 2 outliers for percentage of Bachelor's degree are District of Columbia (D.C.) and Massachusetts. SAT is free in D.C. but not required.

# %%
# Establish figure size.
plt.figure(figsize = (16,9))

ax1 = plt.subplot(3, 3, 1)
ax1.set_title('ACT 2017 Composite Score distribution')
ax1.hist(subset1['act_composite_17']);

ax2 = plt.subplot(3, 3, 2, sharex = ax1)
ax2.set_title('ACT 2018 Composite Score distribution')
ax2.hist(subset1['act_composite_18']);

ax3 = plt.subplot(3, 3, 3, sharex = ax2)
ax3.set_title('ACT 2019 Composite Score distribution')
ax3.hist(subset1['act_composite_19']);

ax1 = plt.subplot(3, 3, 4)
ax1.set_title('SAT 2017 Total Score distribution')
ax1.hist(subset1['sat_total_17']);

ax2 = plt.subplot(3, 3, 5, sharex = ax1)
ax2.set_title('SAT 2018 Total Score distribution')
ax2.hist(subset1['sat_total_18']);

ax3 = plt.subplot(3, 3, 6, sharex = ax2)
ax3.set_title('SAT 2019 Total Score distribution')
ax3.hist(subset1['sat_total_19']);

fig.suptitle('Distribution of Overall Scores for SAT and ACT across years', fontweight = 'bold')
plt.tight_layout()

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %% [markdown]
# Visualise correlation of SAT/ACT subject scores in 2017, since complete subject results are only available for both in 2017

# %%
# Create a dataframe subset of df_sat_act for 2017 data only. Call if df_sat_act_2017.

df_sat_act_2017  = df_us_sat_act[['sat_part_17','sat_ebrw_17','sat_math_17','sat_total_17',
                                           'act_part_17','act_eng_17','act_math_17','act_composite_17',
                                            'act_reading_17','act_science_17']]

df_sat_act_2017.head()
# Out:
#    sat_part_17  sat_ebrw_17  sat_math_17  sat_total_17  act_part_17  \
# 0         0.69          536          524          1060         0.28
# 1         1.00          482          468           950         0.32
# 2         1.00          503          492           996         0.18
# 3         0.93          513          493          1005         0.38
# 4         1.00          509          495          1005         0.29
#
#    act_eng_17  act_math_17  act_composite_17  act_reading_17  act_science_17
# 0        23.3         23.1              23.6            24.2            23.8
# 1        24.4         23.5              24.2            24.9            23.5
# 2        24.1         23.4              24.1            24.8            23.6
# 3        21.9         21.8              22.3            23.0            22.1
# 4        24.1         23.7              24.1            24.5            23.8

# %%
# Correlation table of ACT and SAT individual subjects in 2017 
# Heatmap with masked upper triangle

plt.figure(figsize=(10,10))
plt.title('Heatmap of 2017 SAT and ACT subjects', fontsize = 20) 

mask = np.zeros_like(df_sat_act_2017.corr()) 
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    sns.heatmap(df_sat_act_2017.corr(), mask = mask, annot = True, square = True, vmin = -1, vmax = 1, 
                linewidths = 1)

# %% [markdown]
# Insights
#
# Overall:
# - There is a strong negative correlation between ACT and SAT participation. This suggests that for states with high SAT participation, there is low ACT participation (inversely related).
# - Math scores for both ACT and SAT are negatively correlated.  This is surprising because the states that do better for Math in ACT also do worse than SAT. This could be influenced by the state's policies that we will explore later.
#
# SAT insights:
# - There is very high positive correlation between Math SAT and EBRW SAT scores in 2017, showing that states that do well in one subject also do well in the other subject, which results in higher Total SAT scores as well.
# - Participation rate for ACT and Total/Math/EBRW scores are negatively correlated, showing that states with higher participation have lower mean scores, probably because participation is compulsory or subsidized. In states with lower participation rates, there could be self selection where only the students who are confident in doing well will take the SAT.
#
# ACT insights:
# - Similar to SAT, there is very high positive correlation between all individual ACT subjects with the Composite score. This shows that states that do well in the composite score do well for all subjects.
# - Participation rate for the ACT and individual subject scores are all negatively correlated. This could be due to self selection where only students confident in doing well will take the ACT.

# %%
# Plot histogram to show the distribution of SAT participation and total mean scores 
plt.figure(figsize = (16,9))

ax1 = plt.subplot(3, 2, 1)
ax1.set_title('Distribution of SAT participation in 2017')
ax1.hist(df_us_sat_act['sat_part_17']);

ax1a = plt.subplot(3, 2, 2)
ax1a.set_title('Distribution of SAT Total score in 2017')
ax1a.hist(df_us_sat_act['sat_total_17']);

ax2 = plt.subplot(3, 2, 3)
ax2.set_title('Distribution of SAT participation in 2018')
ax2.hist(df_us_sat_act['sat_part_18']);

ax2a = plt.subplot(3, 2, 4)
ax2a.set_title('Distribution of SAT Total score in 2018')
ax2a.hist(df_us_sat_act['sat_total_18']);

ax3 = plt.subplot(3, 2, 5)
ax3.set_title('Distribution of SAT participation in 2019')
ax3.hist(df_us_sat_act['sat_part_19']);

ax3a = plt.subplot(3, 2, 6)
ax3a.set_title('Distribution of SAT Total score in 2019')
ax3a.hist(df_us_sat_act['sat_total_19']);

plt.tight_layout() 

#Overall chart title, x and y axis of each indiv graph

# %%
# Plot histogram to show the distribution of SAT participation and total mean scores 
plt.figure(figsize = (16,9))

ax1 = plt.subplot(3, 2, 1)
ax1.set_title('Distribution of ACT participation in 2017')
ax1.hist(df_us_sat_act['act_part_17']);

ax1a = plt.subplot(3, 2, 2)
ax1a.set_title('Distribution of ACT Total score in 2017')
ax1a.hist(df_us_sat_act['act_composite_17']);

ax2 = plt.subplot(3, 2, 3)
ax2.set_title('Distribution of ACT participation in 2018')
ax2.hist(df_us_sat_act['act_part_18']);

ax2a = plt.subplot(3, 2, 4)
ax2a.set_title('Distribution of ACT Total score in 2018')
ax2a.hist(df_us_sat_act['act_composite_18']);

ax3 = plt.subplot(3, 2, 5)
ax3.set_title('Distribution of ACT participation in 2019')
ax3.hist(df_us_sat_act['act_part_19']);

ax3a = plt.subplot(3, 2, 6)
ax3a.set_title('Distribution of ACT Total score in 2019')
ax3a.hist(df_us_sat_act['act_composite_19']);

plt.tight_layout()

# %% [markdown]
# From the graphs above, we observe bimodal distribution of histograms, indicating that states perform either very poorly/ very well, or have very high/low participation rates. By looking at the proportion of US states with 100% participation rate, it seems that SAT is gaining popularity while the ACT is losing popularity.

# %% [markdown]
# Next, we plot some scatter plots to show the relationship between participation rates with US Census data (spending, income and education level - using % high schoolers as a proxy).

# %%
g = sns.pairplot(df_us_sat_act, hue= 'is_sat_free', y_vars=['sat_part_17','sat_part_18','sat_part_19'], 
             x_vars=['statespending_perpupil','percapita_income', 'pct_bachelors'])
g.fig.suptitle("Scatter plots of SAT participation against spending, income and education level", y=1.08)
# Out:
# Text(0.5,1.08,'Scatter plots of SAT participation against spending, income and education level')

# %%
g = sns.pairplot(df_us_sat_act, hue= 'is_act_free',y_vars=['act_part_17','act_part_18','act_part_19'], 
             x_vars=['statespending_perpupil','percapita_income', 'pct_bachelors'])
g.fig.suptitle("Scatter plots of ACT participation rate against spending, income and education level", y=1.08)
# Out:
# Text(0.5,1.08,'Scatter plots of ACT participation rate against spending, income and education level')

# %% [markdown]
# Observation: More intuitively for ACT, states that were offered free ACT had mostly 100% participation rates. For the SAT states where testing is offered free but participation rate was low, output the state names in the cell below.

# %%
df_display = df_us_sat_act[df_us_sat_act['is_sat_free'] & (df_us_sat_act['sat_part_19'] <0.3)]

df_display[['state','sat_part_19','sat_part_18','sat_part_17','act_part_19','act_part_18','act_part_17']]
# Out:
#         state  sat_part_19  sat_part_18  sat_part_17  act_part_19  \
# 10   Oklahoma         0.22         0.08         0.07          1.0
# 32       Ohio         0.19         0.18         0.12          1.0
# 39  Tennessee         0.07         0.06         0.05          1.0
#
#     act_part_18  act_part_17
# 10          1.0         1.00
# 32          1.0         0.75
# 39          1.0         1.00

# %% [markdown]
# From our research, students these 3 states (Tennessee, Ohio, Oklahoma) are required to take either the SAT or ACT depending on their district or school, and the it seems that ACT is the preferred test.

# %% [markdown]
# Next, we plot some scatter plots to show the relationship between mean overall scores of SAT and ACT with US Census data (spending, income and education level).

# %%
g = sns.pairplot(df_us_sat_act, hue= 'is_sat_free', y_vars=['sat_total_17','sat_total_18','sat_total_19'], 
             x_vars=['statespending_perpupil','percapita_income', 'pct_bachelors'])
g.fig.suptitle("Scatter plots of SAT mean total scores against spending, income and education level", y=1.08)
# Out:
# Text(0.5,1.08,'Scatter plots of SAT mean total scores against spending, income and education level')

# %%
g = sns.pairplot(df_us_sat_act, hue= 'is_act_free',y_vars=['act_composite_17','act_composite_18','act_composite_19'], 
             x_vars=['statespending_perpupil','percapita_income', 'pct_bachelors'])
g.fig.suptitle("Scatter plots of ACT mean composite scores against spending, income and education level", y=1.08)

#Put the correlation number in the label of the graph individually
# Out:
# Text(0.5,1.08,'Scatter plots of ACT mean composite scores against spending, income and education level')

# %% [markdown]
# US states that were offered free ACT testing as denoted by the orange dots tend to have lower state spending per pupil, lower per capita income and lower percentage of bachelor degree holders in the population. This may be because participation and mean overall scores of both tests are known to be inversely related, which may affect the concentration of low scores in states with high partcipation. To compare more accurately, we should filter first by states that have a high participation in the particular tests (defined by >50% participation, as not many states have >50% participation for both tests).

# %%
df_filter_sat = df_us_sat_act[df_us_sat_act['sat_part_19']>= 0.50]
g = sns.pairplot(df_filter_sat, hue= 'is_sat_free', y_vars=['sat_total_17','sat_total_18','sat_total_19'], 
             x_vars=['statespending_perpupil','percapita_income', 'pct_bachelors'])
g.fig.suptitle("Scatter plots of SAT mean total scores against spending, income and education level", y=1.08)
# Out:
# Text(0.5,1.08,'Scatter plots of SAT mean total scores against spending, income and education level')

# %%
df_filter_sat['state']
# Out:
# 0               Maryland
# 1     DistrictofColumbia
# 2               Delaware
# 3                  Idaho
# 4               Michigan
# 5                Florida
# 6                  Maine
# 7                  Texas
# 8            Connecticut
# 9                Georgia
# 11          NewHampshire
# 12         SouthCarolina
# 13               NewYork
# 14           RhodeIsland
# 15            California
# 16             NewJersey
# 17          WestVirginia
# 18          Pennsylvania
# 19               Indiana
# 21            Washington
# 22         NorthCarolina
# 23              Virginia
# 24                Hawaii
# 25                Oregon
# 26         Massachusetts
# 27               Vermont
# 30              Illinois
# 37              Colorado
# Name: state, dtype: object

# %%
df_filter_act = df_us_sat_act[df_us_sat_act['act_part_19']>= 0.50]

g = sns.pairplot(df_filter_act, hue= 'is_act_free',y_vars=['act_composite_17','act_composite_18','act_composite_19'], 
             x_vars=['statespending_perpupil','percapita_income', 'pct_bachelors'])
g.fig.suptitle("Scatter plots of ACT mean composite scores against spending, income and education level for states that have high ACT participation", y=1.08)
# Out:
# Text(0.5,1.08,'Scatter plots of ACT mean composite scores against spending, income and education level for states that have high ACT participation')

# %%
df_filter_act['state']
# Out:
# 5           Florida
# 10         Oklahoma
# 12    SouthCarolina
# 22    NorthCarolina
# 24           Hawaii
# 28          Arizona
# 29           Nevada
# 31        NewMexico
# 32             Ohio
# 33          Alabama
# 34        Louisiana
# 35          Montana
# 36         Arkansas
# 38      SouthDakota
# 39        Tennessee
# 40          Wyoming
# 41      Mississippi
# 42             Utah
# 43         Kentucky
# 44      NorthDakota
# 45         Nebraska
# 46           Kansas
# 47         Missouri
# 48             Iowa
# 49        Wisconsin
# 50        Minnesota
# Name: state, dtype: object

# %% [markdown]
# From the previous 2 graphs, after filtering, there seems to be no clear difference between the distribution of participation and mean overall scores with

# %%
df_filter_act_subset = df_filter_act[['act_part_17','act_part_18','act_part_19','act_composite_17','act_composite_18','act_composite_19','statespending_perpupil','percapita_income', 'pct_bachelors']]

plt.figure(figsize=(10,10))
plt.title('Heatmap of correlation between SAT participation, total scores \nand spending, income and education level\n of states with high ACT participation', fontsize = 12) 
mask = np.zeros_like(df_filter_act_subset.corr()) 
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    sns.heatmap(df_filter_act_subset.corr(), mask = mask, annot = True, square = True, vmin = -1, vmax = 1, 
                linewidths = 1)

# %% [markdown]
# Out of the states with high ACT participation (>50% in 2019),
# - There is larger correlation between the per capita income and mean ACT composite scores in 2019
# - There is smaller correlation between  state spending on education per pupil and mean ACT composite scores in 2019
#
# - For education level, States that have a higher percentage of bachelor degree holders have higher ACT composite scores as expected, because there are higher rate of college acceptance.
#
# - There is negligible correlation between ACT participation across the years with spending, income and education level.

# %%
df_filter_sat_subset = df_filter_sat[['sat_part_17','sat_part_18','sat_part_19','sat_total_17','sat_total_18','sat_total_19','statespending_perpupil','percapita_income', 'pct_bachelors']]

plt.figure(figsize=(10,10))
plt.title('Heatmap of correlation between SAT participation, total scores \nand spending, income and education level\n of states with high SAT participation', fontsize = 12) 

mask = np.zeros_like(df_filter_sat_subset.corr()) 
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    sns.heatmap(df_filter_sat_subset.corr(), mask = mask, annot = True, square = True, vmin = -1, vmax = 1, 
                linewidths = 1)

# %% [markdown]
# Out of the states with high SAT participation (>50% in 2019),
# - There is larger correlation between the SAT total scores in 2019 and state spending per pupil
# - There is smaller correlation between SAT total scores in 2019 and percapita income
#
# - There is negligible correlation between SAT participation across the years with state spending of education per pupil, and per capita income.
#
# - For education level, States that have a higher percentage of bachelor degree holders have a weaker correlation with higher SAT total scores (corr = 0.19), as opposed to the correlation result from ACT composite scores (0.55).

# %% [markdown]
# Additional food for thought if there is more time for exploration: As compared to states where testing is only required but not free (many options for students), are the states that are both free and required testing doing better?

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Looking at participation rates, SAT seems to be increasing in popularity and ACT decreasing in popularity across 2017 to 2019.

# %% [markdown]
# Interestingly, for states where SAT is provided free, it seems that the SAT total scores per state seem to be inversely related to the state spending, per capita income and percentage of bachelor degree holders and above.
# The opposite trend seems to be true for the states where SAT is not provided for free.
# To encourage higher scores and level the playing ground of states with higher per capita income, the focus should be on more targeted/customized preparation courses for subjects that students are weaker in, instead of simply increasing spending on education.

# %% [markdown]
# As for ACT, there seems to be no clear trend showing that states with free ACT have higher ACT composite scores, hence it is optional for states to decide on their strategy for providing ACT free for students.
